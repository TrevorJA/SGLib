# %% [markdown]
# # Verification and Validation
#
# After generating synthetic flows, two questions follow (Stedinger and
# Taylor, 1982):
#
# - **Verification**: does the ensemble reproduce the statistics the
#   generator was designed to reproduce (moments, correlations,
#   distributional shape)?
# - **Validation**: does the ensemble reproduce characteristics the
#   generator was not explicitly fit to, such as drought duration and
#   severity?
#
# `synhydro.verify` and `synhydro.validate` answer these with the same
# reporting idiom: each statistic is computed once on the observed record
# and once on every realization, and the observed value is compared
# against the distribution of the statistic across realizations.
#
# > **Note:** Run this notebook from the `examples/` directory. Figures are saved to `figures/05_verification/` and data outputs to `outputs/05_verification/` (both are gitignored).

# %%
from pathlib import Path

FIG_DIR = Path("figures") / "05_verification"
OUT_DIR = Path("outputs") / "05_verification"
FIG_DIR.mkdir(parents=True, exist_ok=True)
OUT_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Setup

# %%
import synhydro

Q_daily = synhydro.load_example_data()
Q_monthly = Q_daily.resample("MS").sum()

gen = synhydro.KirschGenerator()
gen.fit(Q_monthly)
ensemble = gen.generate(n_realizations=100, n_years=50, seed=42)

# %% [markdown]
# ## Run verification
#
# Metric selection is explicit: pass `metrics="all"`, or a list of
# category names, metric names, and callables. Categories:
# `marginal`, `temporal`, `seasonal`, `annual`, `spatial`, `fdc`,
# `lmoments`, `extremes`, `spectral`. See the
# [verification API reference](../../api/verification/) for the full
# metric table with citations.

# %%
result = synhydro.verify(ensemble, Q_monthly, metrics="all")

# %% [markdown]
# Or select specific categories and metrics:

# %%
result_subset = synhydro.verify(
    ensemble, Q_monthly,
    metrics=["marginal", "seasonal", "acf"],
)

# %% [markdown]
# ## Read the summary
#
# `result.summary()` returns one row per metric (and per component for
# curve metrics such as monthly means), with the observed value, the
# spread across realizations, and two consistency measures:
#
# - `obs_percentile`: the observed value's position within the synthetic
#   sample, `(n_below + 0.5 n_equal + 0.5) / (n + 1)`. Values near 0.5
#   mean the observed statistic is central in the ensemble; values near
#   0 or 1 mean it lies in the tail.
# - `in_90_band`: whether the observed value falls between the ensemble's
#   5th and 95th percentiles.

# %%
summary = result.summary()
summary[summary["in_90_band"] == False]        # observed outside the ensemble band
# Out:
#      category                    metric    kind                         site  \
# 100  temporal                     hurst  scalar                USGS-01434000
# 101  temporal                     hurst  scalar                USGS-01438500
# 351  seasonal  monthly_lag1_correlation   curve                USGS-01434000
# 363  seasonal  monthly_lag1_correlation   curve                USGS-01438500
# 375  seasonal  monthly_lag1_correlation   curve                USGS-01440000
# 387  seasonal  monthly_lag1_correlation   curve                USGS-01463500
# 508    annual            annual_minimum  scalar                USGS-01434000
# 509    annual            annual_minimum  scalar                USGS-01438500
# 510    annual            annual_minimum  scalar                USGS-01440000
# 511    annual            annual_minimum  scalar                USGS-01463500
# 516   spatial         cross_correlation  matrix  USGS-01434000|USGS-01438500
# 517   spatial         cross_correlation  matrix  USGS-01434000|USGS-01440000
# 518   spatial         cross_correlation  matrix  USGS-01434000|USGS-01463500
# 519   spatial         cross_correlation  matrix  USGS-01438500|USGS-01440000
# 520   spatial         cross_correlation  matrix  USGS-01438500|USGS-01463500
# 521   spatial         cross_correlation  matrix  USGS-01440000|USGS-01463500
# 633  spectral          spectral_density   curve                USGS-01434000
# 634  spectral          spectral_density   curve                USGS-01434000
# 639  spectral          spectral_density   curve                USGS-01438500
# 640  spectral          spectral_density   curve                USGS-01438500
# 645  spectral          spectral_density   curve                USGS-01440000
# 646  spectral          spectral_density   curve                USGS-01440000
# 651  spectral          spectral_density   curve                USGS-01463500
# 652  spectral          spectral_density   curve                USGS-01463500
#
#     component      observed    syn_median      syn_mean       syn_q05  \
# 100       NaN      0.924442      0.721804      0.722484      0.577860
# 101       NaN      0.937157      0.729652      0.723501      0.587401
# 351         8      0.329677      0.584245      0.576486      0.330793
# 363         8      0.343944      0.610894      0.600584      0.375711
# 375         8      0.251185      0.512202      0.518075      0.304973
# 387         8      0.322661      0.568731      0.567934      0.348476
# 508       NaN  22118.940160  28795.066891  28570.705246  23473.432194
# 509       NaN  25035.037339  32062.066658  32230.800438  26304.444749
# 510       NaN    466.483236    581.020168    583.436063    469.594264
# 511       NaN  51437.835003  66323.423604  66854.639899  54574.151065
# 516       NaN      0.997877      0.991325      0.991020      0.988531
# 517       NaN      0.880228      0.835611      0.825374      0.772282
# 518       NaN      0.967247      0.938339      0.937086      0.917702
# 519       NaN      0.891883      0.845942      0.836710      0.788279
# 520       NaN      0.972801      0.947492      0.946809      0.933292
# 521       NaN      0.944060      0.912164      0.906032      0.861854
# 633      1-2y      0.245055      0.094915      0.095096      0.063096
# 634    0.5-1y      0.203623      0.358308      0.358046      0.305586
# 639      1-2y      0.244810      0.094434      0.096022      0.065721
# 640    0.5-1y      0.206544      0.359417      0.361220      0.308891
# 645      1-2y      0.263857      0.105161      0.105622      0.070894
# 646    0.5-1y      0.244650      0.402046      0.392758      0.299572
# 651      1-2y      0.245970      0.103260      0.105278      0.076123
# 652    0.5-1y      0.221060      0.369097      0.365439      0.307547
#
#           syn_q25       syn_q75       syn_q95  obs_percentile in_90_band  \
# 100      0.661962      0.770410      0.866366        0.965347      False
# 101      0.656173      0.768782      0.871130        0.985149      False
# 351      0.514499      0.670833      0.767854        0.054455      False
# 363      0.522726      0.698202      0.769410        0.044554      False
# 375      0.429196      0.615761      0.717570        0.034653      False
# 387      0.494085      0.657244      0.744181        0.044554      False
# 508  26478.393337  30874.248916  34036.350851        0.044554      False
# 509  29683.988784  34896.355904  39555.682397        0.034653      False
# 510    533.676734    633.511944    708.720353        0.054455      False
# 511  60448.868687  72361.835900  81957.916476        0.024752      False
# 516      0.990191      0.991978      0.992936        0.995050      False
# 517      0.816059      0.847314      0.865310        0.995050      False
# 518      0.932370      0.944588      0.949035        0.995050      False
# 519      0.828061      0.857833      0.875181        0.995050      False
# 520      0.942635      0.952237      0.957426        0.995050      False
# 521      0.902047      0.920824      0.932514        0.995050      False
# 633      0.081092      0.107344      0.127558        0.995050      False
# 634      0.331112      0.379710      0.412556        0.004950      False
# 639      0.082471      0.107753      0.130186        0.995050      False
# 640      0.336600      0.384525      0.416615        0.004950      False
# 645      0.090376      0.120861      0.144980        0.995050      False
# 646      0.356787      0.428519      0.468345        0.014851      False
# 651      0.090628      0.118018      0.138595        0.995050      False
# 652      0.334335      0.390580      0.421311        0.004950      False
#
#      relative_diff  reject_rate  n_realizations            units
# 100      -0.219201          NaN             100    dimensionless
# 101      -0.221420          NaN             100    dimensionless
# 351       0.772178          NaN             100    dimensionless
# 363       0.776141          NaN             100    dimensionless
# 375       1.039142          NaN             100    dimensionless
# 387       0.762625          NaN             100    dimensionless
# 508       0.301829          NaN             100  flow_cumulative
# 509       0.280688          NaN             100  flow_cumulative
# 510       0.245533          NaN             100  flow_cumulative
# 511       0.289390          NaN             100  flow_cumulative
# 516      -0.006565          NaN             100    dimensionless
# 517      -0.050688          NaN             100    dimensionless
# 518      -0.029886          NaN             100    dimensionless
# 519      -0.051510          NaN             100    dimensionless
# 520      -0.026016          NaN             100    dimensionless
# 521      -0.033786          NaN             100    dimensionless
# 633      -0.612681          NaN             100    dimensionless
# 634       0.759663          NaN             100    dimensionless
# 639      -0.614255          NaN             100    dimensionless
# 640       0.740144          NaN             100    dimensionless
# 645      -0.601446          NaN             100    dimensionless
# 646       0.643351          NaN             100    dimensionless
# 651      -0.580192          NaN             100    dimensionless
# 652       0.669666          NaN             100    dimensionless

# %%
summary[summary["obs_percentile"] < 0.05]      # ensemble overstates the statistic
# Out:
#      category                    metric    kind           site component  \
# 363  seasonal  monthly_lag1_correlation   curve  USGS-01438500         8
# 375  seasonal  monthly_lag1_correlation   curve  USGS-01440000         8
# 387  seasonal  monthly_lag1_correlation   curve  USGS-01463500         8
# 508    annual            annual_minimum  scalar  USGS-01434000       NaN
# 509    annual            annual_minimum  scalar  USGS-01438500       NaN
# 511    annual            annual_minimum  scalar  USGS-01463500       NaN
# 634  spectral          spectral_density   curve  USGS-01434000    0.5-1y
# 640  spectral          spectral_density   curve  USGS-01438500    0.5-1y
# 646  spectral          spectral_density   curve  USGS-01440000    0.5-1y
# 652  spectral          spectral_density   curve  USGS-01463500    0.5-1y
#
#          observed    syn_median      syn_mean       syn_q05       syn_q25  \
# 363      0.343944      0.610894      0.600584      0.375711      0.522726
# 375      0.251185      0.512202      0.518075      0.304973      0.429196
# 387      0.322661      0.568731      0.567934      0.348476      0.494085
# 508  22118.940160  28795.066891  28570.705246  23473.432194  26478.393337
# 509  25035.037339  32062.066658  32230.800438  26304.444749  29683.988784
# 511  51437.835003  66323.423604  66854.639899  54574.151065  60448.868687
# 634      0.203623      0.358308      0.358046      0.305586      0.331112
# 640      0.206544      0.359417      0.361220      0.308891      0.336600
# 646      0.244650      0.402046      0.392758      0.299572      0.356787
# 652      0.221060      0.369097      0.365439      0.307547      0.334335
#
#           syn_q75       syn_q95  obs_percentile in_90_band  relative_diff  \
# 363      0.698202      0.769410        0.044554      False       0.776141
# 375      0.615761      0.717570        0.034653      False       1.039142
# 387      0.657244      0.744181        0.044554      False       0.762625
# 508  30874.248916  34036.350851        0.044554      False       0.301829
# 509  34896.355904  39555.682397        0.034653      False       0.280688
# 511  72361.835900  81957.916476        0.024752      False       0.289390
# 634      0.379710      0.412556        0.004950      False       0.759663
# 640      0.384525      0.416615        0.004950      False       0.740144
# 646      0.428519      0.468345        0.014851      False       0.643351
# 652      0.390580      0.421311        0.004950      False       0.669666
#
#      reject_rate  n_realizations            units
# 363          NaN             100    dimensionless
# 375          NaN             100    dimensionless
# 387          NaN             100    dimensionless
# 508          NaN             100  flow_cumulative
# 509          NaN             100  flow_cumulative
# 511          NaN             100  flow_cumulative
# 634          NaN             100    dimensionless
# 640          NaN             100    dimensionless
# 646          NaN             100    dimensionless
# 652          NaN             100    dimensionless

# %% [markdown]
# `result.category_summary()` rolls the table up to one row per
# (category, site), using only unit-free quantities so metrics with
# different physical units are never averaged together. There is
# deliberately no single overall score.

# %%
result.category_summary()
# Out:
#     category                          site  n_metrics  n_compared  \
# 0   marginal                 USGS-01434000         11          10
# 1   marginal                 USGS-01438500         11          10
# 2   marginal                 USGS-01440000         11          10
# 3   marginal                 USGS-01463500         11          10
# 4   temporal                 USGS-01434000          4          15
# 5   temporal                 USGS-01438500          4          15
# 6   temporal                 USGS-01440000          4          15
# 7   temporal                 USGS-01463500          4          15
# 8   seasonal                 USGS-01434000          8          72
# 9   seasonal                 USGS-01438500          8          72
# 10  seasonal                 USGS-01440000          8          72
# 11  seasonal                 USGS-01463500          8          72
# 12    annual                 USGS-01434000          7           7
# 13    annual                 USGS-01438500          7           7
# 14    annual                 USGS-01440000          7           7
# 15    annual                 USGS-01463500          7           7
# 16   spatial   USGS-01434000|USGS-01438500          1           1
# 17   spatial   USGS-01434000|USGS-01440000          1           1
# 18   spatial   USGS-01434000|USGS-01463500          1           1
# 19   spatial   USGS-01438500|USGS-01440000          1           1
# 20   spatial   USGS-01438500|USGS-01463500          1           1
# 21   spatial   USGS-01440000|USGS-01463500          1           1
# 22   spatial  USGS-01434000->USGS-01438500          1           1
# 23   spatial  USGS-01434000->USGS-01440000          1           1
# 24   spatial  USGS-01434000->USGS-01463500          1           1
# 25   spatial  USGS-01438500->USGS-01434000          1           1
# 26   spatial  USGS-01438500->USGS-01440000          1           1
# 27   spatial  USGS-01438500->USGS-01463500          1           1
# 28   spatial  USGS-01440000->USGS-01434000          1           1
# 29   spatial  USGS-01440000->USGS-01438500          1           1
# 30   spatial  USGS-01440000->USGS-01463500          1           1
# 31   spatial  USGS-01463500->USGS-01434000          1           1
# 32   spatial  USGS-01463500->USGS-01438500          1           1
# 33   spatial  USGS-01463500->USGS-01440000          1           1
# 34       fdc                 USGS-01434000          2          13
# 35       fdc                 USGS-01438500          2          13
# 36       fdc                 USGS-01440000          2          13
# 37       fdc                 USGS-01463500          2          13
# 38  lmoments                 USGS-01434000          3           3
# 39  lmoments                 USGS-01438500          3           3
# 40  lmoments                 USGS-01440000          3           3
# 41  lmoments                 USGS-01463500          3           3
# 42  extremes                 USGS-01434000          7           7
# 43  extremes                 USGS-01438500          7           7
# 44  extremes                 USGS-01440000          7           7
# 45  extremes                 USGS-01463500          7           7
# 46  spectral                 USGS-01434000          2           7
# 47  spectral                 USGS-01438500          2           7
# 48  spectral                 USGS-01440000          2           7
# 49  spectral                 USGS-01463500          2           7
#
#     n_in_90_band  median_abs_relative_diff  median_obs_percentile_distance
# 0             10                  0.007455                        0.039604
# 1             10                  0.005551                        0.039604
# 2             10                  0.009228                        0.044554
# 3             10                  0.006317                        0.039604
# 4             14                  0.116953                        0.168317
# 5             14                  0.128946                        0.217822
# 6             15                  0.093398                        0.168317
# 7             15                  0.129717                        0.168317
# 8             71                  0.040380                        0.099010
# 9             71                  0.043666                        0.103960
# 10            71                  0.067917                        0.168317
# 11            71                  0.048011                        0.108911
# 12             6                  0.033675                        0.138614
# 13             6                  0.092388                        0.108911
# 14             6                  0.117017                        0.089109
# 15             6                  0.042445                        0.069307
# 16             0                  0.006565                        0.495050
# 17             0                  0.050688                        0.495050
# 18             0                  0.029886                        0.495050
# 19             0                  0.051510                        0.495050
# 20             0                  0.026016                        0.495050
# 21             0                  0.033786                        0.495050
# 22             1                  0.029952                        0.148515
# 23             1                  0.102150                        0.405941
# 24             1                  0.007905                        0.089109
# 25             1                  0.050792                        0.217822
# 26             1                  0.087512                        0.376238
# 27             1                  0.007770                        0.069307
# 28             1                  0.034829                        0.089109
# 29             1                  0.042020                        0.089109
# 30             1                  0.044300                        0.138614
# 31             1                  0.038387                        0.237624
# 32             1                  0.043721                        0.227723
# 33             1                  0.036383                        0.207921
# 34            13                  0.005949                        0.059406
# 35            13                  0.005487                        0.049505
# 36            13                  0.001720                        0.019802
# 37            13                  0.004311                        0.029703
# 38             3                  0.011172                        0.079208
# 39             3                  0.008201                        0.039604
# 40             3                  0.024160                        0.049505
# 41             3                  0.017172                        0.029703
# 42             7                  0.020083                        0.079208
# 43             7                  0.011645                        0.089109
# 44             7                  0.013716                        0.138614
# 45             7                  0.017258                        0.099010
# 46             5                  0.332761                        0.207921
# 47             5                  0.388682                        0.227723
# 48             5                  0.091140                        0.118812
# 49             5                  0.164557                        0.168317

# %% [markdown]
# In a notebook, displaying `result` renders the summary as a styled
# table with the percentile column shaded.
#
# Metrics that could not be computed (for example daily-only low-flow
# metrics on a monthly ensemble) are listed with reasons:

# %%
result.skipped
# Out:
#                metric site                                        reason
# 0  seven_day_min_mean  all  requires ['daily'] data, ensemble is monthly
# 1    seven_day_min_cv  all  requires ['daily'] data, ensemble is monthly

# %% [markdown]
# For custom analysis, the per-realization values are available as a
# tidy DataFrame with one row per (metric, site, component, realization):

# %%
df = result.to_dataframe()
df.head()
# Out:
#    category metric    kind           site component  realization        value  \
# 0  marginal   mean  scalar  USGS-01434000      <NA>            0  4521.710733
# 1  marginal   mean  scalar  USGS-01434000      <NA>            1  4603.175684
# 2  marginal   mean  scalar  USGS-01434000      <NA>            2  4348.589998
# 3  marginal   mean  scalar  USGS-01434000      <NA>            3  4553.832153
# 4  marginal   mean  scalar  USGS-01434000      <NA>            4  4626.539104
#
#       observed units
# 0  4511.235818  flow
# 1  4511.235818  flow
# 2  4511.235818  flow
# 3  4511.235818  flow
# 4  4511.235818  flow

# %% [markdown]
# ## Plot metric distributions
#
# `plot_metric_distributions` shows each scalar metric as a boxplot
# across realizations with the observed value as a dashed line, the
# convention introduced by Stedinger and Taylor (1982):

# %%
from synhydro.plotting import plot_metric_distributions, plot_metric_curve

fig, axes = plot_metric_distributions(result, metrics=["mean", "std", "skewness"])
fig.savefig(FIG_DIR / "metric_distributions.png", dpi=150, bbox_inches="tight")

# %% [markdown]
# Curve metrics (flow duration curve, autocorrelation function, monthly
# statistics) show an ensemble band with the observed curve overlaid:

# %%
fig, ax = plot_metric_curve(result, "fdc", site=Q_monthly.columns[0])
fig.savefig(FIG_DIR / "fdc_curve.png", dpi=150, bbox_inches="tight")

# %% [markdown]
# ## The verification panel
#
# `plot_verification_panel` produces a 5-panel figure comparing observed
# and synthetic distributions by month, including per-realization
# Wilcoxon rank-sum and Levene test p-values. Under a well-performing
# generator, roughly 5 percent of realizations fall below the dashed
# line at p = 0.05.

# %%
from synhydro.plotting import plot_verification_panel

site = Q_monthly.columns[0]
fig, axes = plot_verification_panel(ensemble, observed=Q_monthly[site], site=site)
fig.savefig(FIG_DIR / "verification_panel.png", dpi=150, bbox_inches="tight")

# %% [markdown]
# > **Tip (Log-space comparison):** Streamflow is often right-skewed.
# > Comparing statistics of log-transformed flows can reveal differences in
# > the lower tail:
# > ```python
# > fig, axes = plot_verification_panel(
# >     ensemble, observed=Q_monthly[site], log_space=True
# > )
# > ```

# %% [markdown]
# ## Run validation (drought behavior)
#
# `synhydro.validate` evaluates drought characteristics: run-theory
# events below a flow threshold (`threshold_drought`) and events on the
# Standardized Streamflow Index (`ssi_drought`). See the
# [validation API reference](../../api/validation/).

# %%
val = synhydro.validate(ensemble, Q_monthly, metrics="all")
val.summary()
# Out:
#              category                     metric    kind           site  \
# 0   threshold_drought      mean_drought_duration  scalar  USGS-01434000
# 1   threshold_drought      mean_drought_severity  scalar  USGS-01434000
# 2   threshold_drought       max_drought_duration  scalar  USGS-01434000
# 3   threshold_drought       max_drought_severity  scalar  USGS-01434000
# 4   threshold_drought          drought_frequency  scalar  USGS-01434000
# 5   threshold_drought      mean_drought_duration  scalar  USGS-01438500
# 6   threshold_drought      mean_drought_severity  scalar  USGS-01438500
# 7   threshold_drought       max_drought_duration  scalar  USGS-01438500
# 8   threshold_drought       max_drought_severity  scalar  USGS-01438500
# 9   threshold_drought          drought_frequency  scalar  USGS-01438500
# 10  threshold_drought      mean_drought_duration  scalar  USGS-01440000
# 11  threshold_drought      mean_drought_severity  scalar  USGS-01440000
# 12  threshold_drought       max_drought_duration  scalar  USGS-01440000
# 13  threshold_drought       max_drought_severity  scalar  USGS-01440000
# 14  threshold_drought          drought_frequency  scalar  USGS-01440000
# 15  threshold_drought      mean_drought_duration  scalar  USGS-01463500
# 16  threshold_drought      mean_drought_severity  scalar  USGS-01463500
# 17  threshold_drought       max_drought_duration  scalar  USGS-01463500
# 18  threshold_drought       max_drought_severity  scalar  USGS-01463500
# 19  threshold_drought          drought_frequency  scalar  USGS-01463500
# 20        ssi_drought  ssi_mean_drought_duration  scalar  USGS-01434000
# 21        ssi_drought   ssi_max_drought_duration  scalar  USGS-01434000
# 22        ssi_drought  ssi_mean_drought_severity  scalar  USGS-01434000
# 23        ssi_drought   ssi_max_drought_severity  scalar  USGS-01434000
# 24        ssi_drought      ssi_drought_frequency  scalar  USGS-01434000
# 25        ssi_drought  ssi_mean_drought_duration  scalar  USGS-01438500
# 26        ssi_drought   ssi_max_drought_duration  scalar  USGS-01438500
# 27        ssi_drought  ssi_mean_drought_severity  scalar  USGS-01438500
# 28        ssi_drought   ssi_max_drought_severity  scalar  USGS-01438500
# 29        ssi_drought      ssi_drought_frequency  scalar  USGS-01438500
# 30        ssi_drought  ssi_mean_drought_duration  scalar  USGS-01440000
# 31        ssi_drought   ssi_max_drought_duration  scalar  USGS-01440000
# 32        ssi_drought  ssi_mean_drought_severity  scalar  USGS-01440000
# 33        ssi_drought   ssi_max_drought_severity  scalar  USGS-01440000
# 34        ssi_drought      ssi_drought_frequency  scalar  USGS-01440000
# 35        ssi_drought  ssi_mean_drought_duration  scalar  USGS-01463500
# 36        ssi_drought   ssi_max_drought_duration  scalar  USGS-01463500
# 37        ssi_drought  ssi_mean_drought_severity  scalar  USGS-01463500
# 38        ssi_drought   ssi_max_drought_severity  scalar  USGS-01463500
# 39        ssi_drought      ssi_drought_frequency  scalar  USGS-01463500
#
#     component      observed    syn_median      syn_mean      syn_q05  \
# 0         NaN      2.412500      2.239828      2.277333     1.966855
# 1         NaN    906.530925    855.846835    859.144677   656.193480
# 2         NaN      7.000000      6.000000      6.280000     5.000000
# 3         NaN   5041.842853   3866.064737   3950.655095  2801.379783
# 4         NaN      0.082988      0.088333      0.087950     0.076583
# 5         NaN      2.539474      2.298059      2.322117     2.017186
# 6         NaN   1122.163097   1021.502840   1030.194067   822.579959
# 7         NaN      8.000000      6.000000      6.380000     5.000000
# 8         NaN   5890.017359   4423.898633   4465.353586  3178.304156
# 9         NaN      0.078838      0.085833      0.086350     0.073333
# 10        NaN      2.680556      2.441154      2.470581     2.132430
# 11        NaN     30.728183     28.165570     28.414398    22.605102
# 12        NaN      8.000000      6.000000      6.060000     5.000000
# 13        NaN     98.536963     91.908800     92.908018    70.686386
# 14        NaN      0.074689      0.080000      0.080950     0.070000
# 15        NaN      2.573333      2.417636      2.444668     2.019000
# 16        NaN   2885.794755   2705.150516   2742.161004  2145.347451
# 17        NaN      8.000000      6.000000      6.440000     5.000000
# 18        NaN  13712.772764  10936.722342  11187.088257  8136.397423
# 19        NaN      0.077801      0.081667      0.082750     0.071583
# 20        NaN     22.727273     19.000000     20.154864    13.090179
# 21        NaN     94.000000     46.000000     47.150000    23.000000
# 22        NaN     26.746027     19.033396     19.640510    11.981834
# 23        NaN    115.877467     43.818215     48.396170    26.893895
# 24        NaN      0.138510      0.183362      0.183565     0.141596
# 25        NaN     28.600000     19.916667     20.742221    12.768889
# 26        NaN    119.000000     48.000000     49.050000    23.950000
# 27        NaN     30.713994     19.618107     20.195415    12.080874
# 28        NaN    129.523979     46.435686     49.496396    26.850465
# 29        NaN      0.125918      0.183362      0.179491     0.122241
# 30        NaN     17.687500     18.175000     19.105442    12.853472
# 31        NaN     66.000000     42.000000     45.110000    25.900000
# 32        NaN     18.287593     17.725193     18.070663    10.937021
# 33        NaN     96.398416     42.884177     45.394764    22.304254
# 34        NaN      0.201469      0.203735      0.199253     0.141596
# 35        NaN     21.307692     20.050000     20.986662    12.686458
# 36        NaN     95.000000     45.000000     48.070000    27.900000
# 37        NaN     23.608564     19.847939     20.841609    12.178043
# 38        NaN    128.768073     47.312461     50.859724    25.628891
# 39        NaN      0.163694      0.183362      0.183973     0.122241
#
#         syn_q25       syn_q75       syn_q95  obs_percentile  in_90_band  \
# 0      2.122278      2.394542      2.668333        0.757426        True
# 1    785.894525    948.420047   1049.088248        0.668317        True
# 2      6.000000      7.000000      8.000000        0.816832        True
# 3   3347.226055   4479.273520   5240.889131        0.896040        True
# 4      0.081667      0.092083      0.100083        0.301980        True
# 5      2.168476      2.474682      2.668889        0.836634        True
# 6    932.658116   1138.105012   1272.672884        0.727723        True
# 7      6.000000      7.000000      8.000000        0.965347        True
# 8   3882.181106   5048.880592   5920.940612        0.915842        True
# 9      0.081250      0.091667      0.100083        0.193069        True
# 10     2.338652      2.624275      2.823564        0.816832        True
# 11    26.013088     30.722588     34.235812        0.747525        True
# 12     6.000000      7.000000      7.000000        0.980198       False
# 13    81.777114    101.741143    117.944190        0.668317        True
# 14     0.076667      0.085417      0.091750        0.143564        True
# 15     2.265017      2.618322      2.844730        0.668317        True
# 16  2422.649621   3000.389553   3430.344943        0.648515        True
# 17     6.000000      7.000000      8.000000        0.950495        True
# 18  9647.212370  12383.722460  14583.566608        0.866337        True
# 19     0.076667      0.087083      0.096667        0.262376        True
# 20    16.625000     23.718750     29.502778        0.698020        True
# 21    34.000000     59.000000     76.100000        0.990099       False
# 22    15.607476     23.348465     28.259859        0.886139        True
# 23    35.304766     58.551747     77.652003        0.995050       False
# 24     0.162988      0.203735      0.244482        0.054455       False
# 25    16.676136     24.031250     30.070000        0.935644        True
# 26    35.000000     59.250000     79.100000        0.985149       False
# 27    15.829654     23.511931     30.578563        0.945545       False
# 28    36.588384     59.496984     80.507288        0.995050       False
# 29     0.162988      0.203735      0.244482        0.123762        True
# 30    15.665064     21.800000     27.421667        0.460396        True
# 31    34.000000     52.250000     74.100000        0.856436        True
# 32    14.543926     20.394255     26.522434        0.559406        True
# 33    32.182237     54.441604     80.681722        0.985149       False
# 34     0.178268      0.224109      0.264856        0.391089        True
# 35    16.452020     24.222527     31.891667        0.599010        True
# 36    34.750000     59.250000     78.000000        0.985149       False
# 37    16.312751     24.438765     31.806155        0.698020        True
# 38    37.599387     62.163918     85.033687        0.995050       False
# 39     0.142615      0.224109      0.245501        0.430693        True
#
#     relative_diff  reject_rate  n_realizations            units
# 0       -0.071574          NaN             100        timesteps
# 1       -0.055910          NaN             100  flow_cumulative
# 2       -0.142857          NaN             100        timesteps
# 3       -0.233204          NaN             100  flow_cumulative
# 4        0.064417          NaN             100     per_timestep
# 5       -0.095065          NaN             100        timesteps
# 6       -0.089702          NaN             100  flow_cumulative
# 7       -0.250000          NaN             100        timesteps
# 8       -0.248916          NaN             100  flow_cumulative
# 9        0.088728          NaN             100     per_timestep
# 10      -0.089310          NaN             100        timesteps
# 11      -0.083396          NaN             100  flow_cumulative
# 12      -0.250000          NaN             100        timesteps
# 13      -0.067266          NaN             100  flow_cumulative
# 14       0.071111          NaN             100     per_timestep
# 15      -0.060504          NaN             100        timesteps
# 16      -0.062598          NaN             100  flow_cumulative
# 17      -0.250000          NaN             100        timesteps
# 18      -0.202443          NaN             100  flow_cumulative
# 19       0.049689          NaN             100     per_timestep
# 20      -0.164000          NaN             100        timesteps
# 21      -0.510638          NaN             100        timesteps
# 22      -0.288365          NaN             100    dimensionless
# 23      -0.621857          NaN             100    dimensionless
# 24       0.323815          NaN             100         per_year
# 25      -0.303613          NaN             100        timesteps
# 26      -0.596639          NaN             100        timesteps
# 27      -0.361265          NaN             100    dimensionless
# 28      -0.641490          NaN             100    dimensionless
# 29       0.456197          NaN             100         per_year
# 30       0.027562          NaN             100        timesteps
# 31      -0.363636          NaN             100        timesteps
# 32      -0.030753          NaN             100    dimensionless
# 33      -0.555136          NaN             100    dimensionless
# 34       0.011248          NaN             100         per_year
# 35      -0.059025          NaN             100        timesteps
# 36      -0.526316          NaN             100        timesteps
# 37      -0.159291          NaN             100    dimensionless
# 38      -0.632576          NaN             100    dimensionless
# 39       0.120151          NaN             100         per_year

# %% [markdown]
# Because drought statistics were not fit by the generator, this is the
# stronger test: a generator can verify well and still understate
# multi-year drought severity.
#
# ## Uncertainty and generator comparison
#
# `bootstrap_metric_ci` puts confidence intervals on ensemble metric
# estimates by resampling realizations:

# %%
ci = synhydro.bootstrap_metric_ci(result, n_bootstrap=1000, seed=1)
ci.head()
# Out:
#    category metric           site component      observed      estimate  \
# 0  marginal   mean  USGS-01434000       NaN   4511.235818   4514.525732
# 1  marginal   mean  USGS-01438500       NaN   5143.336687   5142.809205
# 2  marginal   mean  USGS-01440000       NaN    100.506335    101.402675
# 3  marginal   mean  USGS-01463500       NaN  10593.393115  10609.626982
# 4  marginal    std  USGS-01434000       NaN   3269.603194   3245.814727
#
#        ci_lower      ci_upper  relative_diff  rd_ci_lower  rd_ci_upper  \
# 0   4464.884231   4553.394019       0.000729    -0.010275     0.009345
# 1   5089.878374   5203.050524      -0.000103    -0.010394     0.011610
# 2     99.954248    102.296805       0.008918    -0.005493     0.017814
# 3  10492.505786  10770.708395       0.001532    -0.009524     0.016738
# 4   3222.687505   3310.553646      -0.007276    -0.014349     0.012525
#
#    n_realizations
# 0             100
# 1             100
# 2             100
# 3             100
# 4             100

# %% [markdown]
# `compare_methods` tests whether one generator reproduces observed
# statistics better than another, using a paired bootstrap over
# realizations:

# %%
site = Q_monthly.columns[0]

gen_b = synhydro.ThomasFieringGenerator()
gen_b.fit(Q_monthly[[site]])
ensemble_b = gen_b.generate(n_realizations=100, n_years=50, seed=42)

result_b = synhydro.verify(ensemble_b, Q_monthly[[site]], metrics="all")
comparison = synhydro.compare_methods(result, result_b, seed=1)
comparison[comparison["significant"]]
# Out:
# INFO:synhydro.ThomasFieringGenerator:Validated data: 964 timesteps, 1 sites, period 1945-01-01 00:00:00 to 2025-04-01 00:00:00
# INFO:synhydro.ThomasFieringGenerator:Preprocessing complete: 964 months
# INFO:synhydro.ThomasFieringGenerator:Fitting complete: 964 months
# INFO:synhydro.ThomasFieringGenerator:Generated 100 realizations of 50 years each
#      category                           metric           site component  \
# 1    marginal                              std  USGS-01434000      <NA>
# 2    marginal                               cv  USGS-01434000      <NA>
# 3    marginal                         skewness  USGS-01434000      <NA>
# 4    marginal                         kurtosis  USGS-01434000      <NA>
# 5    marginal                          minimum  USGS-01434000      <NA>
# ..        ...                              ...            ...       ...
# 152  extremes                    annual_min_cv  USGS-01434000      <NA>
# 153  spectral                 spectral_density  USGS-01434000       >8y
# 154  spectral                 spectral_density  USGS-01434000      4-8y
# 156  spectral                 spectral_density  USGS-01434000      1-2y
# 159  spectral  low_frequency_variance_fraction  USGS-01434000      <NA>
#
#      method_a_mae  method_b_mae  diff_estimate  diff_ci_lower  diff_ci_upper  \
# 1      140.517129    239.630808     -99.113679    -145.175250     -57.187646
# 2        0.021717      0.043314      -0.021597      -0.028958      -0.014287
# 3        0.151979      0.716057      -0.564078      -0.703603      -0.452419
# 4        0.958836      5.999627      -5.040791      -7.018771      -3.541117
# 5       87.695126    118.171770     -30.476644     -53.167077      -7.995104
# ..            ...           ...            ...            ...            ...
# 152      0.053238      0.081540      -0.028302      -0.043408      -0.013708
# 153      0.025619      0.035466      -0.009847      -0.013236      -0.006025
# 154      0.013904      0.010310       0.003593       0.000674       0.006425
# 156      0.149960      0.136863       0.013096       0.007478       0.018981
# 159      0.023748      0.034733      -0.010984      -0.016571      -0.005439
#
#      significant better_method  paired
# 1           True             a    True
# 2           True             a    True
# 3           True             a    True
# 4           True             a    True
# 5           True             a    True
# ..           ...           ...     ...
# 152         True             a    True
# 153         True             a    True
# 154         True             b    True
# 156         True             b    True
# 159         True             a    True
#
# [92 rows x 12 columns]

# %% [markdown]
# ## Custom metrics
#
# Any function of a series can join the suite:

# %%
from synhydro.verification import register_metric

@register_metric(category="custom", units="flow")
def flow_q25(x):
    """25th percentile of flows."""
    return float(x.quantile(0.25))

result = synhydro.verify(ensemble, Q_monthly, metrics=["marginal", "flow_q25"])

# %% [markdown]
# ## Next steps
#
# - **Metric definitions and citations** - [Verification API](../../api/verification/)
#   and [Validation API](../../api/validation/)
# - **Algorithm details** can help diagnose which statistical properties a
#   generator is designed to preserve - [Algorithms](../../algorithms/index/)
#
# ---
#
# **Previous:** [Working with Ensembles](../04_ensembles/) | **Next:** [Plotting Walkthrough](../06_plotting/)
